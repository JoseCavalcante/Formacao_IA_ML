# %%
# !pip install tpot
# Out:
# Requirement already satisfied: tpot in c:\users\jose\anaconda3\lib\site-packages (0.12.1)
# Requirement already satisfied: numpy>=1.16.3 in c:\users\jose\anaconda3\lib\site-packages (from tpot) (1.24.3)
# Requirement already satisfied: scipy>=1.3.1 in c:\users\jose\anaconda3\lib\site-packages (from tpot) (1.10.1)
# Requirement already satisfied: scikit-learn>=0.22.0 in c:\users\jose\anaconda3\lib\site-packages (from tpot) (1.3.0)
# Requirement already satisfied: deap>=1.2 in c:\users\jose\anaconda3\lib\site-packages (from tpot) (1.4.1)
# Requirement already satisfied: update-checker>=0.16 in c:\users\jose\anaconda3\lib\site-packages (from tpot) (0.18.0)
# Requirement already satisfied: tqdm>=4.36.1 in c:\users\jose\anaconda3\lib\site-packages (from tpot) (4.65.0)
# Requirement already satisfied: stopit>=1.1.1 in c:\users\jose\anaconda3\lib\site-packages (from tpot) (1.1.2)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\jose\anaconda3\lib\site-packages (from tpot) (1.5.3)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\jose\anaconda3\lib\site-packages (from tpot) (1.2.0)
# Requirement already satisfied: xgboost>=1.1.0 in c:\users\jose\anaconda3\lib\site-packages (from tpot) (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\jose\anaconda3\lib\site-packages (from pandas>=0.24.2->tpot) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jose\anaconda3\lib\site-packages (from pandas>=0.24.2->tpot) (2022.7)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\jose\anaconda3\lib\site-packages (from scikit-learn>=0.22.0->tpot) (2.2.0)
# Requirement already satisfied: colorama in c:\users\jose\anaconda3\lib\site-packages (from tqdm>=4.36.1->tpot) (0.4.6)
# Requirement already satisfied: requests>=2.3.0 in c:\users\jose\anaconda3\lib\site-packages (from update-checker>=0.16->tpot) (2.31.0)
# Requirement already satisfied: six>=1.5 in c:\users\jose\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas>=0.24.2->tpot) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jose\anaconda3\lib\site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jose\anaconda3\lib\site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jose\anaconda3\lib\site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jose\anaconda3\lib\site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (2023.7.22)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from tpot import TPOTClassifier
import pandas as pd
from sklearn.preprocessing import LabelEncoder, StandardScaler
# Out:
# C:\Users\Jose\anaconda3\Lib\site-packages\tpot\builtins\__init__.py:36: UserWarning: Warning: optional dependency `torch` is not available. - skipping import of NN models.
#   warnings.warn("Warning: optional dependency `torch` is not available. - skipping import of NN models.")

# %%
dataset = pd.read_csv('credit_simple.csv', sep=';')
dataset.shape
# Out:
# (1000, 8)

# %%
dataset.head()
# Out:
#    SALDO_ATUAL  RESIDENCIADESDE  IDADE OUTROSPLANOSPGTO        DATA  \
# 0       1169.0                4     67           nenhum  01/01/2019
# 1       5951.0                2     22           nenhum  01/01/2020
# 2       2096.0                3     49           nenhum  02/01/2020
# 3       7882.0                4     45           nenhum  02/01/2019
# 4       4870.0                4     53           nenhum  03/01/2018
#
#           ESTADOCIVIL            PROPOSITO CLASSE
# 0  masculino solteiro             radio/tv    bom
# 1         fem div/cas             radio/tv   ruim
# 2  masculino solteiro             educação    bom
# 3  masculino solteiro  mobilia/equipamento    bom
# 4  masculino solteiro           carro novo   ruim

# %%
y = dataset['CLASSE']
X = dataset.iloc[:,:-1]

# %%
#verificar se há dados faltantes
X.isnull().sum()
# Out:
# SALDO_ATUAL         7
# RESIDENCIADESDE     0
# IDADE               0
# OUTROSPLANOSPGTO    0
# DATA                0
# ESTADOCIVIL         8
# PROPOSITO           0
# dtype: int64

# %%
#preenchendo dados faltantes em SALDO_ATUAL pela sua mediana
mediana = X['SALDO_ATUAL'].median()
mediana
# Out:
# 2323.0

# %%
X['SALDO_ATUAL'].fillna(mediana,inplace=True)
X.isnull().sum()
# Out:
# SALDO_ATUAL         0
# RESIDENCIADESDE     0
# IDADE               0
# OUTROSPLANOSPGTO    0
# DATA                0
# ESTADOCIVIL         8
# PROPOSITO           0
# dtype: int64

# %%
#para preencher os dados faltantes de ESTADOCIVIL (categórico) irei utilizar a sua MODA
agrupado = X.groupby(['ESTADOCIVIL']).size()
agrupado
# Out:
# ESTADOCIVIL
# fem div/cas               308
# masculino casado/viuvo     92
# masculino div/sep          50
# masculino solteiro        542
# dtype: int64

# %%
X['ESTADOCIVIL'].fillna('masculino solteiro', inplace=True)
X.isnull().sum()
# Out:
# SALDO_ATUAL         0
# RESIDENCIADESDE     0
# IDADE               0
# OUTROSPLANOSPGTO    0
# DATA                0
# ESTADOCIVIL         0
# PROPOSITO           0
# dtype: int64

# %%
#verifico há outliers no campo SALDO_ATUAL. Vou usar a técnica do DESVIO PADRAO e substituir por sua MEDIANA
desv = X['SALDO_ATUAL'].std()
desv
# Out:
# 685936688.9820064

# %%
#encontrei indicios nos registros de indice 127 e 160. vou susbstituir pela MEDIANA claculada.
X.loc[X['SALDO_ATUAL']>= 2 * desv, 'SALDO_ATUAL']
# Out:
# 127    2.541111e+09
# 160    2.154441e+10
# Name: SALDO_ATUAL, dtype: float64

# %%
mediana = X['SALDO_ATUAL'].median()
mediana
# Out:
# 2323.0

# %%
X.loc[X['SALDO_ATUAL']>= 2 * desv, 'SALDO_ATUAL'] = mediana
X.loc[X['SALDO_ATUAL']>= 2 * desv]
# Out:
# Empty DataFrame
# Columns: [SALDO_ATUAL, RESIDENCIADESDE, IDADE, OUTROSPLANOSPGTO, DATA, ESTADOCIVIL, PROPOSITO]
# Index: []

# %%
#Transformando dados poucos representados em categoria unica (BIDIN)
agrupado = X.groupby(['PROPOSITO']).size()
agrupado
# Out:
# PROPOSITO
# Eletrodomésticos        12
# carro novo             234
# carro usado            103
# educação                50
# mobilia/equipamento    181
# negócios                97
# obras                   22
# outros                  12
# qualificação             9
# radio/tv               280
# dtype: int64

# %%
X.loc[X['PROPOSITO']=='Eletrodomésticos','PROPOSITO'] = 'outros'
X.loc[X['PROPOSITO']=='qualificação','PROPOSITO'] = 'outros'
agrupado = X.groupby(['PROPOSITO']).size()
agrupado
# Out:
# PROPOSITO
# carro novo             234
# carro usado            103
# educação                50
# mobilia/equipamento    181
# negócios                97
# obras                   22
# outros                  33
# radio/tv               280
# dtype: int64

# %%
#extração de características
X['DATA']
# Out:
# 0      01/01/2019
# 1      01/01/2020
# 2      02/01/2020
# 3      02/01/2019
# 4      03/01/2018
#           ...
# 995    29/06/2018
# 996    30/06/2018
# 997    03/07/2018
# 998    04/07/2019
# 999    05/07/2018
# Name: DATA, Length: 1000, dtype: object

# %%
X['DATA'] = pd.to_datetime(X['DATA'], format='%d/%m/%Y')

# %%
X['DATA']
# Out:
# 0     2019-01-01
# 1     2020-01-01
# 2     2020-01-02
# 3     2019-01-02
# 4     2018-01-03
#          ...
# 995   2018-06-29
# 996   2018-06-30
# 997   2018-07-03
# 998   2019-07-04
# 999   2018-07-05
# Name: DATA, Length: 1000, dtype: datetime64[ns]

# %%
X['ANO'] = X['DATA'].dt.year
X['MES'] = X['DATA'].dt.month
X['DIASEMANA'] = X['DATA'].dt.day_name()

# %%
X['ESTADOCIVIL'].unique()
# Out:
# array(['masculino solteiro', 'fem div/cas', 'masculino div/sep',
#        'masculino casado/viuvo'], dtype=object)

# %%
X['PROPOSITO'].unique()
# Out:
# array(['radio/tv', 'educação', 'mobilia/equipamento', 'carro novo',
#        'carro usado', 'negócios', 'outros', 'obras'], dtype=object)

# %%
X['DIASEMANA'].unique()
# Out:
# array(['Tuesday', 'Wednesday', 'Thursday', 'Saturday', 'Sunday', 'Monday',
#        'Friday'], dtype=object)

# %%
labelencoder1 = LabelEncoder()
X['ESTADOCIVIL'] = labelencoder1.fit_transform(X['ESTADOCIVIL'])
X['PROPOSITO'] = labelencoder1.fit_transform(X['PROPOSITO'])
X['DIASEMANA'] = labelencoder1.fit_transform(X['DIASEMANA'])

# %%
X.head()
# Out:
#    SALDO_ATUAL  RESIDENCIADESDE  IDADE OUTROSPLANOSPGTO       DATA  \
# 0       1169.0                4     67           nenhum 2019-01-01
# 1       5951.0                2     22           nenhum 2020-01-01
# 2       2096.0                3     49           nenhum 2020-01-02
# 3       7882.0                4     45           nenhum 2019-01-02
# 4       4870.0                4     53           nenhum 2018-01-03
#
#    ESTADOCIVIL  PROPOSITO   ANO  MES  DIASEMANA
# 0            3          7  2019    1          5
# 1            0          7  2020    1          6
# 2            3          2  2020    1          4
# 3            3          3  2019    1          6
# 4            3          0  2018    1          6

# %%
outros = X['OUTROSPLANOSPGTO'].unique()
outros
# Out:
# array(['nenhum', 'banco', 'stores'], dtype=object)

# %%
z = pd.get_dummies(X['OUTROSPLANOSPGTO'], prefix = 'OUTROS')

# %%
z
# Out:
#      OUTROS_banco  OUTROS_nenhum  OUTROS_stores
# 0               0              1              0
# 1               0              1              0
# 2               0              1              0
# 3               0              1              0
# 4               0              1              0
# ..            ...            ...            ...
# 995             0              1              0
# 996             0              1              0
# 997             0              1              0
# 998             0              1              0
# 999             0              1              0
#
# [1000 rows x 3 columns]

# %%
X
# Out:
#      SALDO_ATUAL  RESIDENCIADESDE  IDADE OUTROSPLANOSPGTO       DATA  \
# 0         1169.0                4     67           nenhum 2019-01-01
# 1         5951.0                2     22           nenhum 2020-01-01
# 2         2096.0                3     49           nenhum 2020-01-02
# 3         7882.0                4     45           nenhum 2019-01-02
# 4         4870.0                4     53           nenhum 2018-01-03
# ..           ...              ...    ...              ...        ...
# 995       1736.0                4     31           nenhum 2018-06-29
# 996       3857.0                4     40           nenhum 2018-06-30
# 997        804.0                4     38           nenhum 2018-07-03
# 998       1845.0                4     23           nenhum 2019-07-04
# 999       4576.0                4     27           nenhum 2018-07-05
#
#      ESTADOCIVIL  PROPOSITO   ANO  MES  DIASEMANA
# 0              3          7  2019    1          5
# 1              0          7  2020    1          6
# 2              3          2  2020    1          4
# 3              3          3  2019    1          6
# 4              3          0  2018    1          6
# ..           ...        ...   ...  ...        ...
# 995            0          3  2018    6          0
# 996            2          1  2018    6          2
# 997            3          7  2018    7          5
# 998            3          7  2019    7          4
# 999            3          1  2018    7          4
#
# [1000 rows x 10 columns]

# %%
sc = StandardScaler()
m = sc.fit_transform(X.iloc[:,0:3])
m
# Out:
# array([[-0.74551643,  1.04698668,  1.6392759 ],
#        [ 0.95774038, -0.76597727, -0.74024139],
#        [-0.41533679,  0.14050471,  0.68746898],
#        ...,
#        [-0.87552244,  1.04698668,  0.1058092 ],
#        [-0.50473818,  1.04698668, -0.68736323],
#        [ 0.46799171,  1.04698668, -0.47585058]])

# %%
X = pd.concat([X,z,pd.DataFrame(m,columns=['SALDO_ATUAL_N','RESIDENCEADESDE_N','IDADE_N'])],axis=1)

# %%
X.head()
# Out:
#    SALDO_ATUAL  RESIDENCIADESDE  IDADE OUTROSPLANOSPGTO       DATA  \
# 0       1169.0                4     67           nenhum 2019-01-01
# 1       5951.0                2     22           nenhum 2020-01-01
# 2       2096.0                3     49           nenhum 2020-01-02
# 3       7882.0                4     45           nenhum 2019-01-02
# 4       4870.0                4     53           nenhum 2018-01-03
#
#    ESTADOCIVIL  PROPOSITO   ANO  MES  DIASEMANA  OUTROS_banco  OUTROS_nenhum  \
# 0            3          7  2019    1          5             0              1
# 1            0          7  2020    1          6             0              1
# 2            3          2  2020    1          4             0              1
# 3            3          3  2019    1          6             0              1
# 4            3          0  2018    1          6             0              1
#
#    OUTROS_stores  SALDO_ATUAL_N  RESIDENCEADESDE_N   IDADE_N
# 0              0      -0.745516           1.046987  1.639276
# 1              0       0.957740          -0.765977 -0.740241
# 2              0      -0.415337           0.140505  0.687469
# 3              0       1.645526           1.046987  0.475956
# 4              0       0.572709           1.046987  0.898982

# %%
X.drop(columns=['SALDO_ATUAL','RESIDENCIADESDE','IDADE','OUTROSPLANOSPGTO','DATA','OUTROS_banco'], inplace=True)

# %%
X
# Out:
#      ESTADOCIVIL  PROPOSITO   ANO  MES  DIASEMANA  OUTROS_nenhum  \
# 0              3          7  2019    1          5              1
# 1              0          7  2020    1          6              1
# 2              3          2  2020    1          4              1
# 3              3          3  2019    1          6              1
# 4              3          0  2018    1          6              1
# ..           ...        ...   ...  ...        ...            ...
# 995            0          3  2018    6          0              1
# 996            2          1  2018    6          2              1
# 997            3          7  2018    7          5              1
# 998            3          7  2019    7          4              1
# 999            3          1  2018    7          4              1
#
#      OUTROS_stores  SALDO_ATUAL_N  RESIDENCEADESDE_N   IDADE_N
# 0                0      -0.745516           1.046987  1.639276
# 1                0       0.957740          -0.765977 -0.740241
# 2                0      -0.415337           0.140505  0.687469
# 3                0       1.645526           1.046987  0.475956
# 4                0       0.572709           1.046987  0.898982
# ..             ...            ...                ...       ...
# 995              0      -0.543562           1.046987 -0.264338
# 996              0       0.211898           1.046987  0.211566
# 997              0      -0.875522           1.046987  0.105809
# 998              0      -0.504738           1.046987 -0.687363
# 999              0       0.467992           1.046987 -0.475851
#
# [1000 rows x 10 columns]

# %%
X_treinamento, X_teste, y_treinamento, y_teste =  train_test_split(X,y, test_size=0.3, random_state=0)

# %%
tpot = TPOTClassifier(
    generations = 100, #numero de geracoes que ele vai criar
    population_size = 100, # numero de configuracoes vai gerar para cada algoritomo gerado (valor padrão)
    offspring_size = 100, # numeros de dencendentes que vai ser gerado (valor padrão)
    mutation_rate =0.9, # taxa de mutação (valor padrão. É a probabilidade de algum elemento receber um valor aleatório)
    crossover_rate=0.1, # valor padrão. é a probabilidade de mistar as soluções
    scoring='accuracy', # metrica de avaliacao dos modelos
    max_time_mins=2, # tempo maximo em minutos por processo de avaliação. definido em 2 min.
    random_state=0, #
    early_stop=False, #interrompe de forma prematura o processo de avaliação
    verbosity=2
)

# %%
tpot.fit(X_treinamento, y_treinamento)
print("Melhor Modelo: ", tpot.fitted_pipeline_)
# Out:
# Optimization Progress:   0%|          | 0/100 [00:00<?, ?pipeline/s]
# Generation 1 - Current best internal CV score: 0.7028571428571428
#
# The optimized pipeline was not improved after evaluating False more generations. Will end the optimization process.
#
# TPOT closed prematurely. Will use the current best pipeline.
#
# Best pipeline: DecisionTreeClassifier(PCA(input_matrix, iterated_power=6, svd_solver=randomized), criterion=gini, max_depth=7, min_samples_leaf=2, min_samples_split=18)
# Melhor Modelo:  Pipeline(steps=[('pca',
#                  PCA(iterated_power=6, random_state=0,
#                      svd_solver='randomized')),
#                 ('decisiontreeclassifier',
#                  DecisionTreeClassifier(max_depth=7, min_samples_leaf=2,
#                                         min_samples_split=18,
#                                         random_state=0))])

# %%
tpot.evaluated_individuals_
# Out:
# {'BernoulliNB(input_matrix, BernoulliNB__alpha=0.001, BernoulliNB__fit_prior=False)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.61},
#  'GaussianNB(PolynomialFeatures(input_matrix, PolynomialFeatures__degree=2, PolynomialFeatures__include_bias=False, PolynomialFeatures__interaction_only=False))': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': 0.49428571428571433},
#  'LogisticRegression(input_matrix, LogisticRegression__C=0.0001, LogisticRegression__dual=False, LogisticRegression__penalty=l2)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6942857142857143},
#  'ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=True, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.9000000000000001, ExtraTreesClassifier__min_samples_leaf=20, ExtraTreesClassifier__min_samples_split=16, ExtraTreesClassifier__n_estimators=100)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6942857142857143},
#  'ExtraTreesClassifier(VarianceThreshold(input_matrix, VarianceThreshold__threshold=0.001), ExtraTreesClassifier__bootstrap=False, ExtraTreesClassifier__criterion=gini, ExtraTreesClassifier__max_features=0.15000000000000002, ExtraTreesClassifier__min_samples_leaf=3, ExtraTreesClassifier__min_samples_split=5, ExtraTreesClassifier__n_estimators=100)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': 0.6942857142857143},
#  'GaussianNB(input_matrix)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.677142857142857},
#  'DecisionTreeClassifier(MinMaxScaler(input_matrix), DecisionTreeClassifier__criterion=gini, DecisionTreeClassifier__max_depth=2, DecisionTreeClassifier__min_samples_leaf=7, DecisionTreeClassifier__min_samples_split=9)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': 0.7014285714285714},
#  'DecisionTreeClassifier(input_matrix, DecisionTreeClassifier__criterion=entropy, DecisionTreeClassifier__max_depth=2, DecisionTreeClassifier__min_samples_leaf=10, DecisionTreeClassifier__min_samples_split=16)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.7014285714285714},
#  'MLPClassifier(CombineDFs(input_matrix, input_matrix), MLPClassifier__alpha=0.1, MLPClassifier__learning_rate_init=0.01)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.38571428571428573},
#  'SGDClassifier(input_matrix, SGDClassifier__alpha=0.01, SGDClassifier__eta0=0.01, SGDClassifier__fit_intercept=True, SGDClassifier__l1_ratio=0.5, SGDClassifier__learning_rate=invscaling, SGDClassifier__loss=modified_huber, SGDClassifier__penalty=elasticnet, SGDClassifier__power_t=100.0)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.3057142857142857},
#  'SGDClassifier(RFE(input_matrix, RFE__ExtraTreesClassifier__criterion=gini, RFE__ExtraTreesClassifier__max_features=0.45, RFE__ExtraTreesClassifier__n_estimators=100, RFE__step=0.35000000000000003), SGDClassifier__alpha=0.0, SGDClassifier__eta0=0.01, SGDClassifier__fit_intercept=True, SGDClassifier__l1_ratio=0.25, SGDClassifier__learning_rate=invscaling, SGDClassifier__loss=perceptron, SGDClassifier__penalty=elasticnet, SGDClassifier__power_t=100.0)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': 0.3057142857142857},
#  'BernoulliNB(input_matrix, BernoulliNB__alpha=0.1, BernoulliNB__fit_prior=True)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6814285714285714},
#  'RandomForestClassifier(RBFSampler(input_matrix, RBFSampler__gamma=0.75), RandomForestClassifier__bootstrap=True, RandomForestClassifier__criterion=gini, RandomForestClassifier__max_features=0.7000000000000001, RandomForestClassifier__min_samples_leaf=1, RandomForestClassifier__min_samples_split=2, RandomForestClassifier__n_estimators=100)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': 0.6857142857142857},
#  'DecisionTreeClassifier(input_matrix, DecisionTreeClassifier__criterion=gini, DecisionTreeClassifier__max_depth=2, DecisionTreeClassifier__min_samples_leaf=19, DecisionTreeClassifier__min_samples_split=15)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.69},
#  'MLPClassifier(input_matrix, MLPClassifier__alpha=0.1, MLPClassifier__learning_rate_init=0.5)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6942857142857143},
#  'MLPClassifier(StandardScaler(input_matrix), MLPClassifier__alpha=0.001, MLPClassifier__learning_rate_init=1.0)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': 0.65},
#  'RandomForestClassifier(input_matrix, RandomForestClassifier__bootstrap=False, RandomForestClassifier__criterion=gini, RandomForestClassifier__max_features=0.2, RandomForestClassifier__min_samples_leaf=18, RandomForestClassifier__min_samples_split=19, RandomForestClassifier__n_estimators=100)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6985714285714286},
#  'GradientBoostingClassifier(RobustScaler(input_matrix), GradientBoostingClassifier__learning_rate=0.01, GradientBoostingClassifier__max_depth=8, GradientBoostingClassifier__max_features=0.6000000000000001, GradientBoostingClassifier__min_samples_leaf=9, GradientBoostingClassifier__min_samples_split=9, GradientBoostingClassifier__n_estimators=100, GradientBoostingClassifier__subsample=0.6500000000000001)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': 0.6957142857142857},
#  'RandomForestClassifier(input_matrix, RandomForestClassifier__bootstrap=False, RandomForestClassifier__criterion=gini, RandomForestClassifier__max_features=0.5, RandomForestClassifier__min_samples_leaf=11, RandomForestClassifier__min_samples_split=13, RandomForestClassifier__n_estimators=100)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6714285714285714},
#  'SGDClassifier(PolynomialFeatures(input_matrix, PolynomialFeatures__degree=2, PolynomialFeatures__include_bias=False, PolynomialFeatures__interaction_only=False), SGDClassifier__alpha=0.0, SGDClassifier__eta0=1.0, SGDClassifier__fit_intercept=True, SGDClassifier__l1_ratio=0.75, SGDClassifier__learning_rate=constant, SGDClassifier__loss=modified_huber, SGDClassifier__penalty=elasticnet, SGDClassifier__power_t=0.0)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': 0.6942857142857143},
#  'BernoulliNB(input_matrix, BernoulliNB__alpha=10.0, BernoulliNB__fit_prior=True)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6828571428571428},
#  'MLPClassifier(input_matrix, MLPClassifier__alpha=0.01, MLPClassifier__learning_rate_init=0.001)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.5528571428571428},
#  'KNeighborsClassifier(input_matrix, KNeighborsClassifier__n_neighbors=72, KNeighborsClassifier__p=1, KNeighborsClassifier__weights=distance)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6942857142857143},
#  'DecisionTreeClassifier(input_matrix, DecisionTreeClassifier__criterion=entropy, DecisionTreeClassifier__max_depth=10, DecisionTreeClassifier__min_samples_leaf=20, DecisionTreeClassifier__min_samples_split=5)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6328571428571429},
#  'ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=False, ExtraTreesClassifier__criterion=gini, ExtraTreesClassifier__max_features=0.9500000000000001, ExtraTreesClassifier__min_samples_leaf=3, ExtraTreesClassifier__min_samples_split=6, ExtraTreesClassifier__n_estimators=100)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6842857142857142},
#  'ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=False, ExtraTreesClassifier__criterion=gini, ExtraTreesClassifier__max_features=0.3, ExtraTreesClassifier__min_samples_leaf=8, ExtraTreesClassifier__min_samples_split=19, ExtraTreesClassifier__n_estimators=100)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6885714285714286},
#  'KNeighborsClassifier(input_matrix, KNeighborsClassifier__n_neighbors=58, KNeighborsClassifier__p=1, KNeighborsClassifier__weights=uniform)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6942857142857143},
#  'MLPClassifier(Binarizer(input_matrix, Binarizer__threshold=0.15000000000000002), MLPClassifier__alpha=0.1, MLPClassifier__learning_rate_init=0.5)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': 0.687142857142857},
#  'ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=True, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=1.0, ExtraTreesClassifier__min_samples_leaf=18, ExtraTreesClassifier__min_samples_split=2, ExtraTreesClassifier__n_estimators=100)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6928571428571428},
#  'BernoulliNB(StandardScaler(input_matrix), BernoulliNB__alpha=1.0, BernoulliNB__fit_prior=True)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': 0.687142857142857},
#  'ExtraTreesClassifier(RBFSampler(input_matrix, RBFSampler__gamma=0.25), ExtraTreesClassifier__bootstrap=True, ExtraTreesClassifier__criterion=gini, ExtraTreesClassifier__max_features=0.7500000000000001, ExtraTreesClassifier__min_samples_leaf=18, ExtraTreesClassifier__min_samples_split=6, ExtraTreesClassifier__n_estimators=100)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': 0.6942857142857143},
#  'BernoulliNB(input_matrix, BernoulliNB__alpha=100.0, BernoulliNB__fit_prior=False)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6857142857142857},
#  'GradientBoostingClassifier(input_matrix, GradientBoostingClassifier__learning_rate=0.5, GradientBoostingClassifier__max_depth=10, GradientBoostingClassifier__max_features=0.2, GradientBoostingClassifier__min_samples_leaf=4, GradientBoostingClassifier__min_samples_split=2, GradientBoostingClassifier__n_estimators=100, GradientBoostingClassifier__subsample=0.45)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6100000000000001},
#  'GaussianNB(FastICA(input_matrix, FastICA__tol=0.25))': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': 0.6814285714285715},
#  'DecisionTreeClassifier(input_matrix, DecisionTreeClassifier__criterion=gini, DecisionTreeClassifier__max_depth=3, DecisionTreeClassifier__min_samples_leaf=17, DecisionTreeClassifier__min_samples_split=17)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6728571428571428},
#  'RandomForestClassifier(FeatureAgglomeration(input_matrix, FeatureAgglomeration__affinity=cosine, FeatureAgglomeration__linkage=average), RandomForestClassifier__bootstrap=True, RandomForestClassifier__criterion=entropy, RandomForestClassifier__max_features=0.3, RandomForestClassifier__min_samples_leaf=14, RandomForestClassifier__min_samples_split=19, RandomForestClassifier__n_estimators=100)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': 0.6957142857142857},
#  'GaussianNB(FastICA(input_matrix, FastICA__tol=1.0))': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': 0.6900000000000001},
#  'KNeighborsClassifier(input_matrix, KNeighborsClassifier__n_neighbors=94, KNeighborsClassifier__p=2, KNeighborsClassifier__weights=distance)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6942857142857143},
#  'ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=False, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.1, ExtraTreesClassifier__min_samples_leaf=18, ExtraTreesClassifier__min_samples_split=20, ExtraTreesClassifier__n_estimators=100)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6942857142857143},
#  'ExtraTreesClassifier(MinMaxScaler(input_matrix), ExtraTreesClassifier__bootstrap=False, ExtraTreesClassifier__criterion=gini, ExtraTreesClassifier__max_features=0.05, ExtraTreesClassifier__min_samples_leaf=15, ExtraTreesClassifier__min_samples_split=12, ExtraTreesClassifier__n_estimators=100)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': 0.6942857142857143},
#  'DecisionTreeClassifier(input_matrix, DecisionTreeClassifier__criterion=gini, DecisionTreeClassifier__max_depth=7, DecisionTreeClassifier__min_samples_leaf=1, DecisionTreeClassifier__min_samples_split=4)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6371428571428571},
#  'ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=True, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.55, ExtraTreesClassifier__min_samples_leaf=8, ExtraTreesClassifier__min_samples_split=6, ExtraTreesClassifier__n_estimators=100)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6857142857142857},
#  'GaussianNB(VarianceThreshold(input_matrix, VarianceThreshold__threshold=0.05))': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': 0.667142857142857},
#  'KNeighborsClassifier(input_matrix, KNeighborsClassifier__n_neighbors=26, KNeighborsClassifier__p=2, KNeighborsClassifier__weights=uniform)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6942857142857143},
#  'BernoulliNB(input_matrix, BernoulliNB__alpha=100.0, BernoulliNB__fit_prior=True)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6971428571428572},
#  'BernoulliNB(input_matrix, BernoulliNB__alpha=0.001, BernoulliNB__fit_prior=True)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6828571428571428},
#  'KNeighborsClassifier(input_matrix, KNeighborsClassifier__n_neighbors=40, KNeighborsClassifier__p=1, KNeighborsClassifier__weights=uniform)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6928571428571428},
#  'DecisionTreeClassifier(RBFSampler(input_matrix, RBFSampler__gamma=0.4), DecisionTreeClassifier__criterion=gini, DecisionTreeClassifier__max_depth=5, DecisionTreeClassifier__min_samples_leaf=3, DecisionTreeClassifier__min_samples_split=9)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': 0.6214285714285714},
#  'DecisionTreeClassifier(CombineDFs(input_matrix, input_matrix), DecisionTreeClassifier__criterion=entropy, DecisionTreeClassifier__max_depth=5, DecisionTreeClassifier__min_samples_leaf=13, DecisionTreeClassifier__min_samples_split=18)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6685714285714286},
#  'MLPClassifier(SelectPercentile(input_matrix, SelectPercentile__percentile=40), MLPClassifier__alpha=0.0001, MLPClassifier__learning_rate_init=0.01)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': 0.6728571428571428},
#  'DecisionTreeClassifier(input_matrix, DecisionTreeClassifier__criterion=gini, DecisionTreeClassifier__max_depth=4, DecisionTreeClassifier__min_samples_leaf=18, DecisionTreeClassifier__min_samples_split=11)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6714285714285715},
#  'SGDClassifier(input_matrix, SGDClassifier__alpha=0.01, SGDClassifier__eta0=0.01, SGDClassifier__fit_intercept=False, SGDClassifier__l1_ratio=0.0, SGDClassifier__learning_rate=invscaling, SGDClassifier__loss=perceptron, SGDClassifier__penalty=elasticnet, SGDClassifier__power_t=0.1)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6942857142857143},
#  'DecisionTreeClassifier(input_matrix, DecisionTreeClassifier__criterion=entropy, DecisionTreeClassifier__max_depth=6, DecisionTreeClassifier__min_samples_leaf=15, DecisionTreeClassifier__min_samples_split=19)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6585714285714286},
#  'SGDClassifier(input_matrix, SGDClassifier__alpha=0.01, SGDClassifier__eta0=1.0, SGDClassifier__fit_intercept=True, SGDClassifier__l1_ratio=0.25, SGDClassifier__learning_rate=constant, SGDClassifier__loss=squared_hinge, SGDClassifier__penalty=elasticnet, SGDClassifier__power_t=0.0)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6942857142857143},
#  'MLPClassifier(input_matrix, MLPClassifier__alpha=0.0001, MLPClassifier__learning_rate_init=0.001)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6642857142857143},
#  'LinearSVC(input_matrix, LinearSVC__C=20.0, LinearSVC__dual=False, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l1, LinearSVC__tol=0.01)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6828571428571429},
#  'KNeighborsClassifier(input_matrix, KNeighborsClassifier__n_neighbors=51, KNeighborsClassifier__p=2, KNeighborsClassifier__weights=uniform)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6942857142857143},
#  'LogisticRegression(input_matrix, LogisticRegression__C=10.0, LogisticRegression__dual=False, LogisticRegression__penalty=l2)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6885714285714286},
#  'GradientBoostingClassifier(input_matrix, GradientBoostingClassifier__learning_rate=0.5, GradientBoostingClassifier__max_depth=1, GradientBoostingClassifier__max_features=0.35000000000000003, GradientBoostingClassifier__min_samples_leaf=17, GradientBoostingClassifier__min_samples_split=14, GradientBoostingClassifier__n_estimators=100, GradientBoostingClassifier__subsample=1.0)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6757142857142858},
#  'KNeighborsClassifier(input_matrix, KNeighborsClassifier__n_neighbors=38, KNeighborsClassifier__p=1, KNeighborsClassifier__weights=distance)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6885714285714286},
#  'LogisticRegression(input_matrix, LogisticRegression__C=0.5, LogisticRegression__dual=False, LogisticRegression__penalty=l2)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6928571428571428},
#  'KNeighborsClassifier(input_matrix, KNeighborsClassifier__n_neighbors=79, KNeighborsClassifier__p=2, KNeighborsClassifier__weights=distance)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6942857142857143},
#  'LogisticRegression(RBFSampler(input_matrix, RBFSampler__gamma=0.2), LogisticRegression__C=5.0, LogisticRegression__dual=False, LogisticRegression__penalty=l2)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': 0.6557142857142857},
#  'LogisticRegression(input_matrix, LogisticRegression__C=0.01, LogisticRegression__dual=False, LogisticRegression__penalty=l2)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6957142857142857},
#  'DecisionTreeClassifier(input_matrix, DecisionTreeClassifier__criterion=gini, DecisionTreeClassifier__max_depth=10, DecisionTreeClassifier__min_samples_leaf=16, DecisionTreeClassifier__min_samples_split=15)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.61},
#  'LinearSVC(input_matrix, LinearSVC__C=10.0, LinearSVC__dual=True, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l2, LinearSVC__tol=0.0001)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6171428571428571},
#  'GradientBoostingClassifier(MinMaxScaler(input_matrix), GradientBoostingClassifier__learning_rate=0.01, GradientBoostingClassifier__max_depth=8, GradientBoostingClassifier__max_features=0.8500000000000001, GradientBoostingClassifier__min_samples_leaf=1, GradientBoostingClassifier__min_samples_split=12, GradientBoostingClassifier__n_estimators=100, GradientBoostingClassifier__subsample=0.05)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': 0.6942857142857143},
#  'DecisionTreeClassifier(input_matrix, DecisionTreeClassifier__criterion=entropy, DecisionTreeClassifier__max_depth=3, DecisionTreeClassifier__min_samples_leaf=19, DecisionTreeClassifier__min_samples_split=9)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6728571428571428},
#  'SGDClassifier(SelectPercentile(input_matrix, SelectPercentile__percentile=4), SGDClassifier__alpha=0.01, SGDClassifier__eta0=0.01, SGDClassifier__fit_intercept=False, SGDClassifier__l1_ratio=1.0, SGDClassifier__learning_rate=constant, SGDClassifier__loss=squared_hinge, SGDClassifier__penalty=elasticnet, SGDClassifier__power_t=0.1)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': 0.6385714285714286},
#  'DecisionTreeClassifier(input_matrix, DecisionTreeClassifier__criterion=gini, DecisionTreeClassifier__max_depth=2, DecisionTreeClassifier__min_samples_leaf=17, DecisionTreeClassifier__min_samples_split=5)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.69},
#  'KNeighborsClassifier(Nystroem(input_matrix, Nystroem__gamma=0.4, Nystroem__kernel=polynomial, Nystroem__n_components=4), KNeighborsClassifier__n_neighbors=81, KNeighborsClassifier__p=1, KNeighborsClassifier__weights=distance)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': 0.6942857142857143},
#  'DecisionTreeClassifier(PCA(input_matrix, PCA__iterated_power=6, PCA__svd_solver=randomized), DecisionTreeClassifier__criterion=entropy, DecisionTreeClassifier__max_depth=7, DecisionTreeClassifier__min_samples_leaf=2, DecisionTreeClassifier__min_samples_split=18)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': 0.6728571428571428},
#  'DecisionTreeClassifier(ZeroCount(input_matrix), DecisionTreeClassifier__criterion=entropy, DecisionTreeClassifier__max_depth=3, DecisionTreeClassifier__min_samples_leaf=16, DecisionTreeClassifier__min_samples_split=16)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': 0.6785714285714286},
#  'DecisionTreeClassifier(input_matrix, DecisionTreeClassifier__criterion=entropy, DecisionTreeClassifier__max_depth=9, DecisionTreeClassifier__min_samples_leaf=5, DecisionTreeClassifier__min_samples_split=5)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6571428571428571},
#  'KNeighborsClassifier(input_matrix, KNeighborsClassifier__n_neighbors=47, KNeighborsClassifier__p=1, KNeighborsClassifier__weights=distance)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6885714285714286},
#  'RandomForestClassifier(input_matrix, RandomForestClassifier__bootstrap=True, RandomForestClassifier__criterion=gini, RandomForestClassifier__max_features=0.3, RandomForestClassifier__min_samples_leaf=19, RandomForestClassifier__min_samples_split=17, RandomForestClassifier__n_estimators=100)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6957142857142857},
#  'KNeighborsClassifier(VarianceThreshold(input_matrix, VarianceThreshold__threshold=0.0001), KNeighborsClassifier__n_neighbors=96, KNeighborsClassifier__p=2, KNeighborsClassifier__weights=distance)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': 0.6942857142857143},
#  'ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=True, ExtraTreesClassifier__criterion=gini, ExtraTreesClassifier__max_features=0.7000000000000001, ExtraTreesClassifier__min_samples_leaf=15, ExtraTreesClassifier__min_samples_split=7, ExtraTreesClassifier__n_estimators=100)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6914285714285715},
#  'DecisionTreeClassifier(CombineDFs(input_matrix, input_matrix), DecisionTreeClassifier__criterion=gini, DecisionTreeClassifier__max_depth=3, DecisionTreeClassifier__min_samples_leaf=15, DecisionTreeClassifier__min_samples_split=2)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6699999999999999},
#  'KNeighborsClassifier(ZeroCount(input_matrix), KNeighborsClassifier__n_neighbors=75, KNeighborsClassifier__p=1, KNeighborsClassifier__weights=uniform)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': 0.6942857142857143},
#  'KNeighborsClassifier(input_matrix, KNeighborsClassifier__n_neighbors=80, KNeighborsClassifier__p=2, KNeighborsClassifier__weights=uniform)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6942857142857143},
#  'ExtraTreesClassifier(Binarizer(input_matrix, Binarizer__threshold=0.0), ExtraTreesClassifier__bootstrap=True, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.55, ExtraTreesClassifier__min_samples_leaf=2, ExtraTreesClassifier__min_samples_split=2, ExtraTreesClassifier__n_estimators=100)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': 0.6885714285714285},
#  'SGDClassifier(Normalizer(input_matrix, Normalizer__norm=l1), SGDClassifier__alpha=0.001, SGDClassifier__eta0=0.01, SGDClassifier__fit_intercept=True, SGDClassifier__l1_ratio=0.25, SGDClassifier__learning_rate=invscaling, SGDClassifier__loss=modified_huber, SGDClassifier__penalty=elasticnet, SGDClassifier__power_t=100.0)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': 0.3057142857142857},
#  'MLPClassifier(input_matrix, MLPClassifier__alpha=0.1, MLPClassifier__learning_rate_init=0.1)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6942857142857143},
#  'MLPClassifier(input_matrix, MLPClassifier__alpha=0.001, MLPClassifier__learning_rate_init=1.0)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6942857142857143},
#  'GradientBoostingClassifier(MaxAbsScaler(input_matrix), GradientBoostingClassifier__learning_rate=1.0, GradientBoostingClassifier__max_depth=5, GradientBoostingClassifier__max_features=0.05, GradientBoostingClassifier__min_samples_leaf=6, GradientBoostingClassifier__min_samples_split=7, GradientBoostingClassifier__n_estimators=100, GradientBoostingClassifier__subsample=0.35000000000000003)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': 0.5714285714285714},
#  'ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=True, ExtraTreesClassifier__criterion=gini, ExtraTreesClassifier__max_features=0.7500000000000001, ExtraTreesClassifier__min_samples_leaf=13, ExtraTreesClassifier__min_samples_split=5, ExtraTreesClassifier__n_estimators=100)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6900000000000001},
#  'SGDClassifier(input_matrix, SGDClassifier__alpha=0.01, SGDClassifier__eta0=1.0, SGDClassifier__fit_intercept=False, SGDClassifier__l1_ratio=0.75, SGDClassifier__learning_rate=invscaling, SGDClassifier__loss=hinge, SGDClassifier__penalty=elasticnet, SGDClassifier__power_t=0.1)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6942857142857143},
#  'SGDClassifier(input_matrix, SGDClassifier__alpha=0.01, SGDClassifier__eta0=1.0, SGDClassifier__fit_intercept=True, SGDClassifier__l1_ratio=0.25, SGDClassifier__learning_rate=constant, SGDClassifier__loss=squared_hinge, SGDClassifier__penalty=elasticnet, SGDClassifier__power_t=0.5)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('SGDClassifier(input_matrix, SGDClassifier__alpha=0.01, SGDClassifier__eta0=1.0, SGDClassifier__fit_intercept=True, SGDClassifier__l1_ratio=0.25, SGDClassifier__learning_rate=constant, SGDClassifier__loss=squared_hinge, SGDClassifier__penalty=elasticnet, SGDClassifier__power_t=0.0)',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6942857142857143},
#  'GradientBoostingClassifier(MinMaxScaler(input_matrix), GradientBoostingClassifier__learning_rate=0.01, GradientBoostingClassifier__max_depth=8, GradientBoostingClassifier__max_features=0.45, GradientBoostingClassifier__min_samples_leaf=1, GradientBoostingClassifier__min_samples_split=12, GradientBoostingClassifier__n_estimators=100, GradientBoostingClassifier__subsample=0.05)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('GradientBoostingClassifier(MinMaxScaler(input_matrix), GradientBoostingClassifier__learning_rate=0.01, GradientBoostingClassifier__max_depth=8, GradientBoostingClassifier__max_features=0.8500000000000001, GradientBoostingClassifier__min_samples_leaf=1, GradientBoostingClassifier__min_samples_split=12, GradientBoostingClassifier__n_estimators=100, GradientBoostingClassifier__subsample=0.05)',),
#   'operator_count': 2,
#   'internal_cv_score': 0.6928571428571428},
#  'ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=False, ExtraTreesClassifier__criterion=gini, ExtraTreesClassifier__max_features=0.05, ExtraTreesClassifier__min_samples_leaf=15, ExtraTreesClassifier__min_samples_split=12, ExtraTreesClassifier__n_estimators=100)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('ExtraTreesClassifier(MinMaxScaler(input_matrix), ExtraTreesClassifier__bootstrap=False, ExtraTreesClassifier__criterion=gini, ExtraTreesClassifier__max_features=0.05, ExtraTreesClassifier__min_samples_leaf=15, ExtraTreesClassifier__min_samples_split=12, ExtraTreesClassifier__n_estimators=100)',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6942857142857143},
#  'KNeighborsClassifier(input_matrix, KNeighborsClassifier__n_neighbors=94, KNeighborsClassifier__p=2, KNeighborsClassifier__weights=uniform)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('KNeighborsClassifier(input_matrix, KNeighborsClassifier__n_neighbors=94, KNeighborsClassifier__p=2, KNeighborsClassifier__weights=distance)',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6942857142857143},
#  'GradientBoostingClassifier(RobustScaler(input_matrix), GradientBoostingClassifier__learning_rate=0.5, GradientBoostingClassifier__max_depth=1, GradientBoostingClassifier__max_features=0.35000000000000003, GradientBoostingClassifier__min_samples_leaf=17, GradientBoostingClassifier__min_samples_split=14, GradientBoostingClassifier__n_estimators=100, GradientBoostingClassifier__subsample=1.0)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('GradientBoostingClassifier(input_matrix, GradientBoostingClassifier__learning_rate=0.5, GradientBoostingClassifier__max_depth=1, GradientBoostingClassifier__max_features=0.35000000000000003, GradientBoostingClassifier__min_samples_leaf=17, GradientBoostingClassifier__min_samples_split=14, GradientBoostingClassifier__n_estimators=100, GradientBoostingClassifier__subsample=1.0)',),
#   'operator_count': 2,
#   'internal_cv_score': 0.6757142857142858},
#  'RandomForestClassifier(CombineDFs(input_matrix, input_matrix), RandomForestClassifier__bootstrap=True, RandomForestClassifier__criterion=entropy, RandomForestClassifier__max_features=0.6000000000000001, RandomForestClassifier__min_samples_leaf=5, RandomForestClassifier__min_samples_split=3, RandomForestClassifier__n_estimators=100)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('DecisionTreeClassifier(CombineDFs(input_matrix, input_matrix), DecisionTreeClassifier__criterion=gini, DecisionTreeClassifier__max_depth=3, DecisionTreeClassifier__min_samples_leaf=15, DecisionTreeClassifier__min_samples_split=2)',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6785714285714285},
#  'SGDClassifier(input_matrix, SGDClassifier__alpha=0.0, SGDClassifier__eta0=0.01, SGDClassifier__fit_intercept=True, SGDClassifier__l1_ratio=0.25, SGDClassifier__learning_rate=invscaling, SGDClassifier__loss=perceptron, SGDClassifier__penalty=elasticnet, SGDClassifier__power_t=100.0)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('SGDClassifier(RFE(input_matrix, RFE__ExtraTreesClassifier__criterion=gini, RFE__ExtraTreesClassifier__max_features=0.45, RFE__ExtraTreesClassifier__n_estimators=100, RFE__step=0.35000000000000003), SGDClassifier__alpha=0.0, SGDClassifier__eta0=0.01, SGDClassifier__fit_intercept=True, SGDClassifier__l1_ratio=0.25, SGDClassifier__learning_rate=invscaling, SGDClassifier__loss=perceptron, SGDClassifier__penalty=elasticnet, SGDClassifier__power_t=100.0)',),
#   'operator_count': 1,
#   'internal_cv_score': 0.3057142857142857},
#  'KNeighborsClassifier(input_matrix, KNeighborsClassifier__n_neighbors=97, KNeighborsClassifier__p=2, KNeighborsClassifier__weights=distance)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('KNeighborsClassifier(input_matrix, KNeighborsClassifier__n_neighbors=94, KNeighborsClassifier__p=2, KNeighborsClassifier__weights=distance)',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6942857142857143},
#  'DecisionTreeClassifier(input_matrix, DecisionTreeClassifier__criterion=entropy, DecisionTreeClassifier__max_depth=10, DecisionTreeClassifier__min_samples_leaf=20, DecisionTreeClassifier__min_samples_split=19)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('DecisionTreeClassifier(input_matrix, DecisionTreeClassifier__criterion=entropy, DecisionTreeClassifier__max_depth=10, DecisionTreeClassifier__min_samples_leaf=20, DecisionTreeClassifier__min_samples_split=5)',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6328571428571429},
#  'MLPClassifier(input_matrix, MLPClassifier__alpha=0.0001, MLPClassifier__learning_rate_init=0.1)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('MLPClassifier(input_matrix, MLPClassifier__alpha=0.1, MLPClassifier__learning_rate_init=0.1)',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6985714285714286},
#  'SGDClassifier(PolynomialFeatures(input_matrix, PolynomialFeatures__degree=2, PolynomialFeatures__include_bias=False, PolynomialFeatures__interaction_only=False), SGDClassifier__alpha=0.0, SGDClassifier__eta0=1.0, SGDClassifier__fit_intercept=True, SGDClassifier__l1_ratio=0.5, SGDClassifier__learning_rate=constant, SGDClassifier__loss=modified_huber, SGDClassifier__penalty=elasticnet, SGDClassifier__power_t=0.0)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('SGDClassifier(PolynomialFeatures(input_matrix, PolynomialFeatures__degree=2, PolynomialFeatures__include_bias=False, PolynomialFeatures__interaction_only=False), SGDClassifier__alpha=0.0, SGDClassifier__eta0=1.0, SGDClassifier__fit_intercept=True, SGDClassifier__l1_ratio=0.75, SGDClassifier__learning_rate=constant, SGDClassifier__loss=modified_huber, SGDClassifier__penalty=elasticnet, SGDClassifier__power_t=0.0)',),
#   'operator_count': 2,
#   'internal_cv_score': 0.6942857142857143},
#  'KNeighborsClassifier(input_matrix, KNeighborsClassifier__n_neighbors=51, KNeighborsClassifier__p=2, KNeighborsClassifier__weights=distance)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('KNeighborsClassifier(input_matrix, KNeighborsClassifier__n_neighbors=51, KNeighborsClassifier__p=2, KNeighborsClassifier__weights=uniform)',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6942857142857143},
#  'ExtraTreesClassifier(MaxAbsScaler(input_matrix), ExtraTreesClassifier__bootstrap=False, ExtraTreesClassifier__criterion=gini, ExtraTreesClassifier__max_features=0.9500000000000001, ExtraTreesClassifier__min_samples_leaf=3, ExtraTreesClassifier__min_samples_split=6, ExtraTreesClassifier__n_estimators=100)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=False, ExtraTreesClassifier__criterion=gini, ExtraTreesClassifier__max_features=0.9500000000000001, ExtraTreesClassifier__min_samples_leaf=3, ExtraTreesClassifier__min_samples_split=6, ExtraTreesClassifier__n_estimators=100)',),
#   'operator_count': 2,
#   'internal_cv_score': 0.6842857142857142},
#  'DecisionTreeClassifier(CombineDFs(input_matrix, input_matrix), DecisionTreeClassifier__criterion=gini, DecisionTreeClassifier__max_depth=5, DecisionTreeClassifier__min_samples_leaf=13, DecisionTreeClassifier__min_samples_split=18)': {'generation': 1,
#   'mutation_count': 0,
#   'crossover_count': 1,
#   'predecessor': ('DecisionTreeClassifier(CombineDFs(input_matrix, input_matrix), DecisionTreeClassifier__criterion=entropy, DecisionTreeClassifier__max_depth=5, DecisionTreeClassifier__min_samples_leaf=13, DecisionTreeClassifier__min_samples_split=18)',
#    'DecisionTreeClassifier(CombineDFs(input_matrix, input_matrix), DecisionTreeClassifier__criterion=gini, DecisionTreeClassifier__max_depth=3, DecisionTreeClassifier__min_samples_leaf=15, DecisionTreeClassifier__min_samples_split=2)'),
#   'operator_count': 1,
#   'internal_cv_score': 0.6371428571428571},
#  'DecisionTreeClassifier(input_matrix, DecisionTreeClassifier__criterion=entropy, DecisionTreeClassifier__max_depth=3, DecisionTreeClassifier__min_samples_leaf=16, DecisionTreeClassifier__min_samples_split=16)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('DecisionTreeClassifier(ZeroCount(input_matrix), DecisionTreeClassifier__criterion=entropy, DecisionTreeClassifier__max_depth=3, DecisionTreeClassifier__min_samples_leaf=16, DecisionTreeClassifier__min_samples_split=16)',),
#   'operator_count': 1,
#   'internal_cv_score': 0.677142857142857},
#  'MLPClassifier(input_matrix, MLPClassifier__alpha=0.001, MLPClassifier__learning_rate_init=0.001)': {'generation': 1,
#   'mutation_count': 0,
#   'crossover_count': 1,
#   'predecessor': ('MLPClassifier(input_matrix, MLPClassifier__alpha=0.0001, MLPClassifier__learning_rate_init=0.001)',
#    'MLPClassifier(input_matrix, MLPClassifier__alpha=0.001, MLPClassifier__learning_rate_init=1.0)'),
#   'operator_count': 1,
#   'internal_cv_score': 0.5942857142857143},
#  'BernoulliNB(input_matrix, BernoulliNB__alpha=0.01, BernoulliNB__fit_prior=True)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('KNeighborsClassifier(input_matrix, KNeighborsClassifier__n_neighbors=51, KNeighborsClassifier__p=2, KNeighborsClassifier__weights=uniform)',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6814285714285714},
#  'RandomForestClassifier(input_matrix, RandomForestClassifier__bootstrap=False, RandomForestClassifier__criterion=gini, RandomForestClassifier__max_features=0.5, RandomForestClassifier__min_samples_leaf=18, RandomForestClassifier__min_samples_split=13, RandomForestClassifier__n_estimators=100)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('RandomForestClassifier(input_matrix, RandomForestClassifier__bootstrap=False, RandomForestClassifier__criterion=gini, RandomForestClassifier__max_features=0.5, RandomForestClassifier__min_samples_leaf=11, RandomForestClassifier__min_samples_split=13, RandomForestClassifier__n_estimators=100)',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6857142857142857},
#  'BernoulliNB(ZeroCount(input_matrix), BernoulliNB__alpha=10.0, BernoulliNB__fit_prior=True)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('BernoulliNB(input_matrix, BernoulliNB__alpha=10.0, BernoulliNB__fit_prior=True)',),
#   'operator_count': 2,
#   'internal_cv_score': 0.6814285714285714},
#  'LogisticRegression(RBFSampler(MinMaxScaler(input_matrix), RBFSampler__gamma=0.2), LogisticRegression__C=5.0, LogisticRegression__dual=False, LogisticRegression__penalty=l2)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('LogisticRegression(RBFSampler(input_matrix, RBFSampler__gamma=0.2), LogisticRegression__C=5.0, LogisticRegression__dual=False, LogisticRegression__penalty=l2)',),
#   'operator_count': 3,
#   'internal_cv_score': 0.6885714285714286},
#  'ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=True, ExtraTreesClassifier__criterion=gini, ExtraTreesClassifier__max_features=0.7000000000000001, ExtraTreesClassifier__min_samples_leaf=6, ExtraTreesClassifier__min_samples_split=7, ExtraTreesClassifier__n_estimators=100)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=True, ExtraTreesClassifier__criterion=gini, ExtraTreesClassifier__max_features=0.7000000000000001, ExtraTreesClassifier__min_samples_leaf=15, ExtraTreesClassifier__min_samples_split=7, ExtraTreesClassifier__n_estimators=100)',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6900000000000001},
#  'KNeighborsClassifier(RFE(input_matrix, RFE__ExtraTreesClassifier__criterion=gini, RFE__ExtraTreesClassifier__max_features=0.45, RFE__ExtraTreesClassifier__n_estimators=100, RFE__step=0.35000000000000003), KNeighborsClassifier__n_neighbors=98, KNeighborsClassifier__p=1, KNeighborsClassifier__weights=uniform)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('SGDClassifier(RFE(input_matrix, RFE__ExtraTreesClassifier__criterion=gini, RFE__ExtraTreesClassifier__max_features=0.45, RFE__ExtraTreesClassifier__n_estimators=100, RFE__step=0.35000000000000003), SGDClassifier__alpha=0.0, SGDClassifier__eta0=0.01, SGDClassifier__fit_intercept=True, SGDClassifier__l1_ratio=0.25, SGDClassifier__learning_rate=invscaling, SGDClassifier__loss=perceptron, SGDClassifier__penalty=elasticnet, SGDClassifier__power_t=100.0)',),
#   'operator_count': 2,
#   'internal_cv_score': 0.6942857142857143},
#  'GaussianNB(StandardScaler(input_matrix))': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('GaussianNB(input_matrix)',),
#   'operator_count': 2,
#   'internal_cv_score': 0.677142857142857},
#  'KNeighborsClassifier(input_matrix, KNeighborsClassifier__n_neighbors=47, KNeighborsClassifier__p=2, KNeighborsClassifier__weights=distance)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('KNeighborsClassifier(input_matrix, KNeighborsClassifier__n_neighbors=47, KNeighborsClassifier__p=1, KNeighborsClassifier__weights=distance)',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6957142857142857},
#  'KNeighborsClassifier(input_matrix, KNeighborsClassifier__n_neighbors=72, KNeighborsClassifier__p=2, KNeighborsClassifier__weights=distance)': {'generation': 1,
#   'mutation_count': 0,
#   'crossover_count': 1,
# ...
#   'operator_count': 1,
#   'internal_cv_score': 0.6628571428571429},
#  'GaussianNB(FastICA(input_matrix, FastICA__tol=0.8))': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('GaussianNB(FastICA(input_matrix, FastICA__tol=1.0))',),
#   'operator_count': 2,
#   'internal_cv_score': 0.6842857142857144},
#  'LinearSVC(input_matrix, LinearSVC__C=0.1, LinearSVC__dual=False, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l1, LinearSVC__tol=0.001)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('BernoulliNB(input_matrix, BernoulliNB__alpha=100.0, BernoulliNB__fit_prior=True)',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6885714285714285},
#  'DecisionTreeClassifier(input_matrix, DecisionTreeClassifier__criterion=gini, DecisionTreeClassifier__max_depth=5, DecisionTreeClassifier__min_samples_leaf=3, DecisionTreeClassifier__min_samples_split=9)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('DecisionTreeClassifier(RBFSampler(input_matrix, RBFSampler__gamma=0.4), DecisionTreeClassifier__criterion=gini, DecisionTreeClassifier__max_depth=5, DecisionTreeClassifier__min_samples_leaf=3, DecisionTreeClassifier__min_samples_split=9)',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6528571428571428},
#  'SGDClassifier(input_matrix, SGDClassifier__alpha=0.001, SGDClassifier__eta0=1.0, SGDClassifier__fit_intercept=False, SGDClassifier__l1_ratio=0.25, SGDClassifier__learning_rate=invscaling, SGDClassifier__loss=modified_huber, SGDClassifier__penalty=elasticnet, SGDClassifier__power_t=0.0)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('MLPClassifier(input_matrix, MLPClassifier__alpha=0.0001, MLPClassifier__learning_rate_init=0.001)',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6942857142857143},
#  'GradientBoostingClassifier(input_matrix, GradientBoostingClassifier__learning_rate=1.0, GradientBoostingClassifier__max_depth=5, GradientBoostingClassifier__max_features=0.05, GradientBoostingClassifier__min_samples_leaf=6, GradientBoostingClassifier__min_samples_split=7, GradientBoostingClassifier__n_estimators=100, GradientBoostingClassifier__subsample=0.35000000000000003)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('GradientBoostingClassifier(MaxAbsScaler(input_matrix), GradientBoostingClassifier__learning_rate=1.0, GradientBoostingClassifier__max_depth=5, GradientBoostingClassifier__max_features=0.05, GradientBoostingClassifier__min_samples_leaf=6, GradientBoostingClassifier__min_samples_split=7, GradientBoostingClassifier__n_estimators=100, GradientBoostingClassifier__subsample=0.35000000000000003)',),
#   'operator_count': 1,
#   'internal_cv_score': 0.5814285714285715},
#  'DecisionTreeClassifier(CombineDFs(input_matrix, input_matrix), DecisionTreeClassifier__criterion=entropy, DecisionTreeClassifier__max_depth=5, DecisionTreeClassifier__min_samples_leaf=13, DecisionTreeClassifier__min_samples_split=9)': {'generation': 1,
#   'mutation_count': 0,
#   'crossover_count': 1,
#   'predecessor': ('DecisionTreeClassifier(CombineDFs(input_matrix, input_matrix), DecisionTreeClassifier__criterion=entropy, DecisionTreeClassifier__max_depth=5, DecisionTreeClassifier__min_samples_leaf=13, DecisionTreeClassifier__min_samples_split=18)',
#    'DecisionTreeClassifier(RBFSampler(input_matrix, RBFSampler__gamma=0.4), DecisionTreeClassifier__criterion=gini, DecisionTreeClassifier__max_depth=5, DecisionTreeClassifier__min_samples_leaf=3, DecisionTreeClassifier__min_samples_split=9)'),
#   'operator_count': 1,
#   'internal_cv_score': 0.6685714285714286},
#  'LinearSVC(input_matrix, LinearSVC__C=0.1, LinearSVC__dual=True, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l2, LinearSVC__tol=0.0001)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('LinearSVC(input_matrix, LinearSVC__C=10.0, LinearSVC__dual=True, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l2, LinearSVC__tol=0.0001)',),
#   'operator_count': 1,
#   'internal_cv_score': 0.54},
#  'SGDClassifier(PolynomialFeatures(input_matrix, PolynomialFeatures__degree=2, PolynomialFeatures__include_bias=False, PolynomialFeatures__interaction_only=False), SGDClassifier__alpha=0.0, SGDClassifier__eta0=1.0, SGDClassifier__fit_intercept=False, SGDClassifier__l1_ratio=0.75, SGDClassifier__learning_rate=constant, SGDClassifier__loss=modified_huber, SGDClassifier__penalty=elasticnet, SGDClassifier__power_t=0.0)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('SGDClassifier(PolynomialFeatures(input_matrix, PolynomialFeatures__degree=2, PolynomialFeatures__include_bias=False, PolynomialFeatures__interaction_only=False), SGDClassifier__alpha=0.0, SGDClassifier__eta0=1.0, SGDClassifier__fit_intercept=True, SGDClassifier__l1_ratio=0.75, SGDClassifier__learning_rate=constant, SGDClassifier__loss=modified_huber, SGDClassifier__penalty=elasticnet, SGDClassifier__power_t=0.0)',),
#   'operator_count': 2,
#   'internal_cv_score': 0.6942857142857143},
#  'DecisionTreeClassifier(MaxAbsScaler(input_matrix), DecisionTreeClassifier__criterion=gini, DecisionTreeClassifier__max_depth=2, DecisionTreeClassifier__min_samples_leaf=17, DecisionTreeClassifier__min_samples_split=5)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('DecisionTreeClassifier(input_matrix, DecisionTreeClassifier__criterion=gini, DecisionTreeClassifier__max_depth=2, DecisionTreeClassifier__min_samples_leaf=17, DecisionTreeClassifier__min_samples_split=5)',),
#   'operator_count': 2,
#   'internal_cv_score': 0.69},
#  'BernoulliNB(input_matrix, BernoulliNB__alpha=1.0, BernoulliNB__fit_prior=True)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('BernoulliNB(input_matrix, BernoulliNB__alpha=0.001, BernoulliNB__fit_prior=True)',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6814285714285714},
#  'KNeighborsClassifier(input_matrix, KNeighborsClassifier__n_neighbors=35, KNeighborsClassifier__p=2, KNeighborsClassifier__weights=uniform)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('KNeighborsClassifier(input_matrix, KNeighborsClassifier__n_neighbors=51, KNeighborsClassifier__p=2, KNeighborsClassifier__weights=uniform)',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6900000000000001},
#  'DecisionTreeClassifier(MinMaxScaler(input_matrix), DecisionTreeClassifier__criterion=entropy, DecisionTreeClassifier__max_depth=2, DecisionTreeClassifier__min_samples_leaf=7, DecisionTreeClassifier__min_samples_split=9)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('DecisionTreeClassifier(MinMaxScaler(input_matrix), DecisionTreeClassifier__criterion=gini, DecisionTreeClassifier__max_depth=2, DecisionTreeClassifier__min_samples_leaf=7, DecisionTreeClassifier__min_samples_split=9)',),
#   'operator_count': 2,
#   'internal_cv_score': 0.7014285714285714},
#  'ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=True, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=1.0, ExtraTreesClassifier__min_samples_leaf=5, ExtraTreesClassifier__min_samples_split=2, ExtraTreesClassifier__n_estimators=100)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=True, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=1.0, ExtraTreesClassifier__min_samples_leaf=18, ExtraTreesClassifier__min_samples_split=2, ExtraTreesClassifier__n_estimators=100)',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6942857142857142},
#  'ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=True, ExtraTreesClassifier__criterion=gini, ExtraTreesClassifier__max_features=0.1, ExtraTreesClassifier__min_samples_leaf=5, ExtraTreesClassifier__min_samples_split=4, ExtraTreesClassifier__n_estimators=100)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('GaussianNB(input_matrix)',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6942857142857143},
#  'MLPClassifier(input_matrix, MLPClassifier__alpha=0.1, MLPClassifier__learning_rate_init=0.01)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('MLPClassifier(CombineDFs(input_matrix, input_matrix), MLPClassifier__alpha=0.1, MLPClassifier__learning_rate_init=0.01)',),
#   'operator_count': 1,
#   'internal_cv_score': 0.5814285714285715},
#  'SGDClassifier(input_matrix, SGDClassifier__alpha=0.0, SGDClassifier__eta0=1.0, SGDClassifier__fit_intercept=True, SGDClassifier__l1_ratio=0.75, SGDClassifier__learning_rate=constant, SGDClassifier__loss=modified_huber, SGDClassifier__penalty=elasticnet, SGDClassifier__power_t=0.0)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('SGDClassifier(PolynomialFeatures(input_matrix, PolynomialFeatures__degree=2, PolynomialFeatures__include_bias=False, PolynomialFeatures__interaction_only=False), SGDClassifier__alpha=0.0, SGDClassifier__eta0=1.0, SGDClassifier__fit_intercept=True, SGDClassifier__l1_ratio=0.75, SGDClassifier__learning_rate=constant, SGDClassifier__loss=modified_huber, SGDClassifier__penalty=elasticnet, SGDClassifier__power_t=0.0)',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6942857142857143},
#  'KNeighborsClassifier(Nystroem(input_matrix, Nystroem__gamma=0.30000000000000004, Nystroem__kernel=polynomial, Nystroem__n_components=4), KNeighborsClassifier__n_neighbors=81, KNeighborsClassifier__p=1, KNeighborsClassifier__weights=distance)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('KNeighborsClassifier(Nystroem(input_matrix, Nystroem__gamma=0.4, Nystroem__kernel=polynomial, Nystroem__n_components=4), KNeighborsClassifier__n_neighbors=81, KNeighborsClassifier__p=1, KNeighborsClassifier__weights=distance)',),
#   'operator_count': 2,
#   'internal_cv_score': 0.6942857142857143},
#  'ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=True, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=1.0, ExtraTreesClassifier__min_samples_leaf=18, ExtraTreesClassifier__min_samples_split=14, ExtraTreesClassifier__n_estimators=100)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=True, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=1.0, ExtraTreesClassifier__min_samples_leaf=18, ExtraTreesClassifier__min_samples_split=2, ExtraTreesClassifier__n_estimators=100)',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6928571428571428},
#  'DecisionTreeClassifier(input_matrix, DecisionTreeClassifier__criterion=gini, DecisionTreeClassifier__max_depth=6, DecisionTreeClassifier__min_samples_leaf=1, DecisionTreeClassifier__min_samples_split=7)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('GaussianNB(input_matrix)',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6757142857142857},
#  'MLPClassifier(RBFSampler(input_matrix, RBFSampler__gamma=0.55), MLPClassifier__alpha=0.001, MLPClassifier__learning_rate_init=1.0)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('MLPClassifier(StandardScaler(input_matrix), MLPClassifier__alpha=0.001, MLPClassifier__learning_rate_init=1.0)',),
#   'operator_count': 2,
#   'internal_cv_score': 0.6514285714285715},
#  'KNeighborsClassifier(input_matrix, KNeighborsClassifier__n_neighbors=75, KNeighborsClassifier__p=1, KNeighborsClassifier__weights=uniform)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('KNeighborsClassifier(ZeroCount(input_matrix), KNeighborsClassifier__n_neighbors=75, KNeighborsClassifier__p=1, KNeighborsClassifier__weights=uniform)',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6942857142857143},
#  'KNeighborsClassifier(input_matrix, KNeighborsClassifier__n_neighbors=72, KNeighborsClassifier__p=1, KNeighborsClassifier__weights=uniform)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('KNeighborsClassifier(input_matrix, KNeighborsClassifier__n_neighbors=72, KNeighborsClassifier__p=1, KNeighborsClassifier__weights=distance)',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6942857142857143},
#  'BernoulliNB(MaxAbsScaler(input_matrix), BernoulliNB__alpha=0.001, BernoulliNB__fit_prior=False)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('BernoulliNB(input_matrix, BernoulliNB__alpha=0.001, BernoulliNB__fit_prior=False)',),
#   'operator_count': 2,
#   'internal_cv_score': 0.61},
#  'GaussianNB(MinMaxScaler(VarianceThreshold(input_matrix, VarianceThreshold__threshold=0.05)))': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('GaussianNB(VarianceThreshold(input_matrix, VarianceThreshold__threshold=0.05))',),
#   'operator_count': 3,
#   'internal_cv_score': 0.667142857142857},
#  'DecisionTreeClassifier(input_matrix, DecisionTreeClassifier__criterion=gini, DecisionTreeClassifier__max_depth=8, DecisionTreeClassifier__min_samples_leaf=16, DecisionTreeClassifier__min_samples_split=12)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('KNeighborsClassifier(input_matrix, KNeighborsClassifier__n_neighbors=94, KNeighborsClassifier__p=2, KNeighborsClassifier__weights=distance)',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6185714285714285},
#  'DecisionTreeClassifier(input_matrix, DecisionTreeClassifier__criterion=entropy, DecisionTreeClassifier__max_depth=10, DecisionTreeClassifier__min_samples_leaf=13, DecisionTreeClassifier__min_samples_split=16)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('BernoulliNB(input_matrix, BernoulliNB__alpha=0.1, BernoulliNB__fit_prior=True)',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6357142857142857},
#  'LinearSVC(input_matrix, LinearSVC__C=1.0, LinearSVC__dual=True, LinearSVC__loss=hinge, LinearSVC__penalty=l2, LinearSVC__tol=0.01)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('GaussianNB(input_matrix)',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6171428571428571},
#  'ExtraTreesClassifier(MinMaxScaler(input_matrix), ExtraTreesClassifier__bootstrap=False, ExtraTreesClassifier__criterion=gini, ExtraTreesClassifier__max_features=0.05, ExtraTreesClassifier__min_samples_leaf=15, ExtraTreesClassifier__min_samples_split=10, ExtraTreesClassifier__n_estimators=100)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('ExtraTreesClassifier(MinMaxScaler(input_matrix), ExtraTreesClassifier__bootstrap=False, ExtraTreesClassifier__criterion=gini, ExtraTreesClassifier__max_features=0.05, ExtraTreesClassifier__min_samples_leaf=15, ExtraTreesClassifier__min_samples_split=12, ExtraTreesClassifier__n_estimators=100)',),
#   'operator_count': 2,
#   'internal_cv_score': 0.6942857142857143},
#  'SGDClassifier(input_matrix, SGDClassifier__alpha=0.01, SGDClassifier__eta0=0.01, SGDClassifier__fit_intercept=False, SGDClassifier__l1_ratio=0.0, SGDClassifier__learning_rate=invscaling, SGDClassifier__loss=squared_hinge, SGDClassifier__penalty=elasticnet, SGDClassifier__power_t=50.0)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('BernoulliNB(input_matrix, BernoulliNB__alpha=0.001, BernoulliNB__fit_prior=False)',),
#   'operator_count': 1,
#   'internal_cv_score': 0.3057142857142857}}

# %%
previsao = tpot.predict(X_teste)
acuracia = accuracy_score(previsao, y_teste)
print(f"Acurácia: {acuracia}")
# Out:
# Acurácia: 0.6966666666666667
